# %% [markdown]
# <a href="https://colab.research.google.com/github/Elmasri-Fathallah/Data-Analysis/blob/master/Agents_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
june_19 = pd.read_csv('june_19.csv', sep=',',header=0)
july_19 = pd.read_csv('july_19.csv', sep=',',header=0)
aug_19 = pd.read_csv('aug_19.csv', sep=',',header=0)
sept_19 = pd.read_csv('sept_19.csv', sep=',',header=0)
oct_19 = pd.read_csv('oct_19.csv', sep=',',header=0)
nov_19 = pd.read_csv('nov_19.csv', sep=',',header=0)

# %%
june_19 = june_19.drop(columns=['Column1','Unnamed: 0'])

# %% [markdown]
# # New Section

# %%
june_19
# Out:
#                                      Name   ACD Login  ...  Column3 Unnamed: 48
# 0                                 Overall  3867:49:34  ...      NaN         NaN
# 1                             Aoun, Kevin    70:50:12  ...  0:10:14         NaN
# 2            Yassen, Sameh Othman Mohamed    83:17:51  ...  0:06:13         NaN
# 3               Abuhamra, Abdelrahman A.A    84:09:44  ...  0:07:32         NaN
# 4   Sayed, Mohammad Moneer Mohammad Yehia    59:56:19  ...  0:07:27         NaN
# 5                 Mahareeq, Ahmed Mohamed    70:53:45  ...  0:08:27         NaN
# 6                               Adi, Iyas   135:36:55  ...  0:06:45         NaN
# 7                 Lail, Fouad Ahmed Fouad    44:38:57  ...  0:06:50         NaN
# 8                      Alshourbagi, Jalal   174:04:45  ...  0:06:24         NaN
# 9             Alhawali, Ahmad Abdulmannan   167:42:12  ...  0:06:26         NaN
# 10              Alsaeed Alhaj Ahmad, Majd   120:08:25  ...  0:07:46         NaN
# ...

# %%
july_19
# Out:
#                                      Name   ACD Login  ...          Team     Site
# 0                                 Overall  5555:16:45  ...           NaN      NaN
# 1                            Masoud, Anas    98:17:26  ...        Mshwah   Berlin
# 2                 Mahareeq, Ahmed Mohamed    91:30:08  ...        Mshwah   Berlin
# 3                          Nour, Mohammad    57:40:44  ...       Elmasri   Berlin
# 4                       Al Haddad, Khaled   174:57:11  ...        Mshwah   Berlin
# 5                          Marcos, Bashar   151:29:24  ...        Mshwah   Berlin
# 6                        Abudayyeh, Qusai   103:58:58  ...       Elmasri   Berlin
# 7                       Elmeshaky, Nermin   171:41:12  ...       Elmasri   Berlin
# 8     Elmasri, Fathallah Ismail Saleh Ali    21:50:25  ...  Team Manager   Berlin
# 9             Elbastawy, Inas Samir Sayed   192:46:17  ...       Elmasri   Berlin
# ...

# %%
aug_19
# Out:
#                                      Name   ACD Login  ...          Team     Site
# 0                                 Overall  5555:16:45  ...           NaN      NaN
# 1                            Masoud, Anas    98:17:26  ...        Mshwah   Berlin
# 2                 Mahareeq, Ahmed Mohamed    91:30:08  ...        Mshwah   Berlin
# 3                          Nour, Mohammad    57:40:44  ...       Elmasri   Berlin
# 4                       Al Haddad, Khaled   174:57:11  ...        Mshwah   Berlin
# 5                          Marcos, Bashar   151:29:24  ...        Mshwah   Berlin
# 6                        Abudayyeh, Qusai   103:58:58  ...       Elmasri   Berlin
# 7                       Elmeshaky, Nermin   171:41:12  ...       Elmasri   Berlin
# 8     Elmasri, Fathallah Ismail Saleh Ali    21:50:25  ...  Team Manager   Berlin
# 9             Elbastawy, Inas Samir Sayed   192:46:17  ...       Elmasri   Berlin
# ...

# %%
sept_19
# Out:
#                                         Name   ACD Login  ...     Team     Site
# 0                                    Overall  3678:42:28  ...      NaN      NaN
# 1                           Hussein, Mohamed    77:21:01  ...  Elmasri   Berlin
# 2                Elbastawy, Inas Samir Sayed    89:12:27  ...  Elmasri   Berlin
# 3                            Alkurdi, Mayiar   167:29:05  ...  Elmasri   Berlin
# 4                             Alkotob, Ghada   159:39:25  ...   Mshwah   Berlin
# 5                              Hafez, Bisher   154:55:11  ...   Mshwah   Berlin
# 6                             Nour, Mohammad    34:19:20  ...  Elmasri   Berlin
# 7                          Elmeshaky, Nermin   133:25:40  ...  Elmasri   Berlin
# 8                                Mahdi, Dana    38:18:11  ...  Elmasri   Berlin
# 9                 Osman, Tamer A-Ragab Osman   173:07:49  ...  Mentors   Berlin
# 10                 Alsaeed Alhaj Ahmad, Majd    62:03:27  ...   Mshwah   Berlin
# ...

# %%
oct_19
# Out:
#                                         Name   ACD Login  ...     Team     Site
# 0                                    Overall  4229:25:48  ...      NaN      NaN
# 1                        Ezzaldeen, Montaser     8:46:10  ...   Mshwah   Berlin
# 2                          Hachachna, Mounir    89:16:04  ...  Elmasri  BERHome
# 3               Yassen, Sameh Othman Mohamed    31:39:04  ...   Mshwah   Berlin
# 4                          Al Haddad, Khaled    26:11:28  ...   Mshwah   Berlin
# 5                    Mahareeq, Ahmed Mohamed    94:20:29  ...   Mshwah   Berlin
# 6                Alhawali, Ahmad Abdulmannan    16:17:08  ...   Mshwah   Berlin
# 7                           Hussein, Mohamed    51:01:54  ...  Elmasri   Berlin
# 8   Elhakim, Heidi Hany Zaki Suliman Mohamed    98:54:07  ...   Mshwah   Berlin
# 9                                Mahdi, Dana   100:52:11  ...  Elmasri   Berlin
# 10     Hassan, Mohamed Mohamed Ashraf Salama    85:22:55  ...  Elmasri   Berlin
# ...

# %%
nov_19
# Out:
#                                         Name   ACD Login  ...     Team     Site
# 0                                    Overall  3542:54:53  ...      NaN      NaN
# 1           Elsharabassi, Ahmed Atef Ibrahim    56:35:42  ...   Mshwah   Berlin
# 2                 Alagrab, Ahmed Abdelfattah    64:06:55  ...   Mshwah   Berlin
# 3                              Moualla, Yara    60:01:00  ...   Mshwah   Berlin
# 4                    Mahareeq, Ahmed Mohamed    14:04:01  ...   Mshwah   Berlin
# 5                          Hachachna, Mounir   107:41:08  ...  Elmasri  BERHome
# 6                          Aldarwish, Bashar    93:45:05  ...   Mshwah   Berlin
# 7   Elhakim, Heidi Hany Zaki Suliman Mohamed    75:40:16  ...   Mshwah   Berlin
# 8                           Abudayyeh, Qusai    25:57:46  ...  Elmasri   Berlin
# 9                Sharaky, Samar Ahmed Hassan    29:21:28  ...  Elmasri   Berlin
# 10                          Hussein, Mohamed    49:27:46  ...  Elmasri   Berlin
# ...

# %%
year_19 = pd.concat(['jun_19','july_19','aug_19','sept_19','oct_19','nov_19'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-c3e48e73a5e3> in <module>()
# ----> 1 year_19 = pd.concat(['jun_19','july_19','aug_19','sept_19','oct_19','nov_19'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     355                     "only Series and DataFrame objs are valid".format(typ=type(obj))
#     356                 )
# --> 357                 raise TypeError(msg)
#     358
#     359             # consolidate
#
# ...

# %%
print(nov_19.dtypes)
# Out:
# Name                   object
# ACD Login              object
# Hand                    int64
# AHT                    object
# ATT                    object
# ACW                    object
# HLD                    object
# Ring                   object
# Avail                  object
# E-Mail Hand             int64
# Avail + AUX8           object
# Break AUX1+AUX2        object
# Lunch AUX1             object
# Short AUX2             object
# Social AUX21           object
# Research AUX3          object
# L2/L3/PSN AUX31        object
# Training AUX4         float64
# Training AUX5          object
# Nesting AUX51          object
# PEP/QM AUX52           object
# Callback AUX6         float64
# Mentoring AUX7         object
# E-Mail AUX8            object
# Meeting AUX9           object
# System Issue AUX91     object
# Login AUX0             object
# Case Logs               int64
# Log.%                  object
# Short.%                object
# NPS                    object
# ...
